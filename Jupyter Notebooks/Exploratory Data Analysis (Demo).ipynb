# %%
# Libraries
import requests
import os
import pandas as pd

# Not used yet, but imported for possible later use
import json

# %%
# Load CSV based on generation number; return error message for invalid val
def load_poke_csv(gen_val):
    try:
        gen_df = pd.read_csv(f'../data/gen{gen_val}_pokemon_stats.csv', sep=',')
    except FileNotFoundError:
        print(f"Invalid generation number: {gen_val}")
        return
    return gen_df

# %%
# Load CSV into DataFrame
gen1_df = load_poke_csv(1)

# %%
# Do some exploratory DataFrame review by...
# Returning first 10 entries, sorted by HP in descending order:
gen1_df.sort_values(by=['hp'], ascending=False).head(10)
# Out:
#       hp  attack  defense  special-attack  special-defense  speed   type_1  \
# 112  250       5        5              35              105     50   normal
# 142  160     110       65              65              110     30   normal
# 39   140      70       45              85               50     45   normal
# 130  130      85       80              85               95     60    water
# 133  130      65       60             110               95     65    water
# 38   115      45       20              45               25     20   normal
# 149  106     110       90             154               90    130  psychic
# 88   105     105       75              65              100     50   poison
# 111  105     130      120              45               45     40   ground
# 114  105      95       80              40               80     90   normal
#
#     type_2     Pokemon  totalstat
# 112    NaN     chansey        450
# 142    NaN     snorlax        540
# 39   fairy  wigglytuff        435
# 130    ice      lapras        535
# 133    NaN    vaporeon        525
# 38   fairy  jigglypuff        270
# 149    NaN      mewtwo        680
# 88     NaN         muk        500
# 111   rock      rhydon        485
# 114    NaN  kangaskhan        490

# %%
# Demonstrate that we know how to handle NaN values:
gen1_df['type_2'] = gen1_df['type_2'].fillna('N/A')
gen1_df.head()
# Out:
#    hp  attack  defense  special-attack  special-defense  speed type_1  type_2  \
# 0  45      49       49              65               65     45  grass  poison
# 1  60      62       63              80               80     60  grass  poison
# 2  80      82       83             100              100     80  grass  poison
# 3  39      52       43              60               50     65   fire     N/A
# 4  58      64       58              80               65     80   fire     N/A
#
#       Pokemon  totalstat
# 0   bulbasaur        318
# 1     ivysaur        405
# 2    venusaur        525
# 3  charmander        309
# 4  charmeleon        405

# %%
# Demonstrate case changing:
gen1_df['type_1'] = gen1_df['type_1'].str.upper()
gen1_df['type_2'] = gen1_df['type_2'].str.upper()
gen1_df['Pokemon'] = gen1_df['Pokemon'].str.title()
gen1_df.tail()
# Out:
#       hp  attack  defense  special-attack  special-defense  speed   type_1  \
# 146   41      64       45              50               50     50   DRAGON
# 147   61      84       65              70               70     70   DRAGON
# 148   91     134       95             100              100     80   DRAGON
# 149  106     110       90             154               90    130  PSYCHIC
# 150  100     100      100             100              100    100  PSYCHIC
#
#      type_2    Pokemon  totalstat
# 146     N/A    Dratini        300
# 147     N/A  Dragonair        420
# 148  FLYING  Dragonite        600
# 149     N/A     Mewtwo        680
# 150     N/A        Mew        600

# %%
# Demonstrate filtering (e.g. by min value threshold):
gen1_df.loc[gen1_df['attack'] >= 120]
# Out:
#       hp  attack  defense  special-attack  special-defense  speed    type_1  \
# 67    90     130       80              65               85     55  FIGHTING
# 75    80     120      130              55               65     45      ROCK
# 98    55     130      115              50               50     75     WATER
# 105   50     120       53              35              110     87  FIGHTING
# 111  105     130      120              45               45     40    GROUND
# 126   65     125      100              55               70     85       BUG
# 129   95     125       79              60              100     81     WATER
# 135   65     130       60              95              110     65      FIRE
# 148   91     134       95             100              100     80    DRAGON
#
#      type_2    Pokemon  totalstat
# 67      N/A    Machamp        505
# 75   GROUND      Golem        495
# 98      N/A    Kingler        475
# 105     N/A  Hitmonlee        455
# 111    ROCK     Rhydon        485
# 126     N/A     Pinsir        500
# 129  FLYING   Gyarados        540
# 135     N/A    Flareon        525
# 148  FLYING  Dragonite        600

# %%
# Add new column (e.g. joint "power" value):
gen1_df['power'] = (gen1_df['attack'] + gen1_df['special-attack']) // 2
gen1_df.head()
# Out:
#    hp  attack  defense  special-attack  special-defense  speed type_1  type_2  \
# 0  45      49       49              65               65     45  GRASS  POISON
# 1  60      62       63              80               80     60  GRASS  POISON
# 2  80      82       83             100              100     80  GRASS  POISON
# 3  39      52       43              60               50     65   FIRE     N/A
# 4  58      64       58              80               65     80   FIRE     N/A
#
#       Pokemon  totalstat  power
# 0   Bulbasaur        318     57
# 1     Ivysaur        405     71
# 2    Venusaur        525     91
# 3  Charmander        309     56
# 4  Charmeleon        405     72

# %%
# Put revised data into new CSV:
gen1_df.to_csv('../data/gen1_EDA_demo.csv', index=False)
